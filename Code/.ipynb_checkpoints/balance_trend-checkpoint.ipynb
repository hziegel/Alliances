# %%
# Visualize the trend in triad balance of the network over previous 10 years
# Heron Ziegel
# 915986142

import numpy as np
import pandas as pd
import networkx as nx
import itertools
import matplotlib.pyplot as plt
import math
import glob
import re

# %%
import ipynb.fs.full.utility_functions as util
import ipynb.fs.full.visualize_graph as vis

# %%
# UPDATE THESE VARIABLES TO CHANGE THE DATA & APPEARANCE

# Path where the data is stored
DATA_FILEPATH = '../Data/Timeline/'

# integer 1-6, changes how the graph visuals appear
SEED = 6

# %%
# Fill the array with graphs based on each CSV file in the folder (one CSV file = one year's network data)
timeline_graphs = {}

# Iterate over all CSV files in folder, create a new graph and append it to timeline_graphs
for file_name in glob.glob(DATA_FILEPATH+'*.csv'):
    df = pd.read_csv(file_name, index_col=0)
    input_data = df.to_numpy()
    column_names = df.columns
    G = util.newGraph(input_data, column_names)
    timeline_graphs[file_name[-8:-4]] = G

print(timeline_graphs)
# Out:
# {'2021': <networkx.classes.graph.Graph object at 0x1397aac50>, '2020': <networkx.classes.graph.Graph object at 0x12d574b90>, '2016': <networkx.classes.graph.Graph object at 0x1394df6d0>, '2017': <networkx.classes.graph.Graph object at 0x1397d8450>, '2019': <networkx.classes.graph.Graph object at 0x1392b3590>, '2018': <networkx.classes.graph.Graph object at 0x139765550>, '2022': <networkx.classes.graph.Graph object at 0x139398d90>, '2023': <networkx.classes.graph.Graph object at 0x1397ef910>, '2024': <networkx.classes.graph.Graph object at 0x12d534650>, '2025': <networkx.classes.graph.Graph object at 0x1397f9f10>}

# %%
# Create X and Y arrays with the year and structural balance
x = []
y = []

for i in timeline_graphs:
    y.append(util.structural_balance(timeline_graphs[i]))
    x.append(i)

# Manually sort x by date, simultaneously sort y to match it
n = len(x)
for i in range(n):
    for j in range(0, n-i-1):
        if x[j] > x[j+1]:
            x[j], x[j+1] = x[j+1], x[j]
            y[j], y[j+1] = y[j+1], y[j]

print(x)
print(y)
# Out:
# ['2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
# [0.13333333333333333, 0.13333333333333333, 0.13333333333333333, 0.13333333333333333, 0.13333333333333333, 0.1393939393939394, 0.15757575757575756, 0.16363636363636364, 0.16363636363636364, 0.15151515151515152]

# %%
# Visualize the structural balance as a line graph

plt.plot(x, y)
plt.xlabel("Year")
plt.ylabel("Balance")
plt.title("Structural Balance Over Time")
plt.show()

# %%
# This is the balance index. Create an imbalance to align with the CoW data using the inverse.
y_imbalance = [1 - a for a in y]

plt.plot(x, y_imbalance)
plt.xlabel("Year")
plt.ylabel("Imbalance")
plt.title("Structural Imbalance Over Time")
plt.show()

# %%
# Generate a CSV with the imbalance data
df1 = pd.DataFrame({"Year" : x, "Imbalance" : y_imbalance})
df1.to_csv("../Data/imbalance_trend.csv", index=False)
